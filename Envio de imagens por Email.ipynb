# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "name": "Envio de E-mail com Anexo - Python.ipynb",
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": 155,
      "metadata": {
        "id": "2MtoaodEXrOp"
      },
      "outputs": [],
      "source": [
        "import smtplib\n",
        "\n",
        "from email.mime.multipart import MIMEMultipart\n",
        "from email.mime.text import MIMEText\n",
        "from email.mime.image import MIMEImage\n",
        "\n",
        "# para o anexo\n",
        "from email.mime.base import MIMEBase\n",
        "from email import encoders"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# S M T P - Simple Mail transfer protocol\n",
        "# Para criar o servidor e enviar o e-mail\n",
        "#https://www.youtube.com/watch?v=umvzsQLZYD4\n",
        "#https://erikasarti.com/html/dingbats-simbolos-desenhos/\n"
      ],
      "metadata": {
        "id": "PrpRlLvTYBh3"
      },
      "execution_count": 3,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "# 1 - STARTAR O SERVIDOR SMTP\n",
        "host = \"smtp.gmail.com\"\n",
        "port = \"587\"\n",
        "login = ''\n",
        "senha = ''\n",
        "\n",
        "server = smtplib.SMTP(host,port)\n",
        "\n",
        "server.ehlo()\n",
        "server.starttls()\n",
        "\n",
        "server.login(login,senha)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "7TGRZI1ObZTh",
        "outputId": "22c87855-b857-44cd-8900-ecdd237afcfa"
      },
      "execution_count": 185,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "(235, b'2.7.0 Accepted')"
            ]
          },
          "metadata": {},
          "execution_count": 185
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# 2 - CONTRUIR O EMAIL TIPO MIME\n",
        "\n",
        "corpo = '<b style = \"color: pink\">Olá, tudo bem? &hearts; </b> <img scr=\"Foto.jpeg\" alt = \"foto do Nero\">'\n",
        "email_msg = MIMEMultipart()\n",
        "email_msg['From'] = login\n",
        "email_msg['To'] = 'deboraadotto@gmail.com'\n",
        "email_msg['Subject'] = \"Meu e-mail teste_v2\"\n",
        "email_msg.attach(MIMEText(corpo,'html'))\n",
        "\n",
        "# anexo de arquivo\n",
        "#abrimos o arquivo em modo leitura e binary\n",
        "cam_arquivo = \"Foto.jpeg\"\n",
        "attchment = open(cam_arquivo,'rb') # r de ready e b de binary (leitura binária)\n",
        "\n",
        "# lemos o arquivo no modo binario e jogamos codificado em base 64 (que é o que o e-mail precisa)\n",
        "att = MIMEBase('application','octet-stream')\n",
        "att.set_payload(attchment.read())\n",
        "encoders.encode_base64(att)\n",
        "\n",
        "#adicionamos o cabeçalho no tipo anexo de e-mail\n",
        "att.add_header('Content-Disposition',f'attachment; filename=Foto.jpeg')\n",
        "attchment.close()\n",
        "email_msg.attach(att)"
      ],
      "metadata": {
        "id": "90-_n-hcchF2"
      },
      "execution_count": 182,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "# 3 - ENVIAR O EMAIL tipo MIME no SERVIDOR SMTP\n",
        "server.sendmail(email_msg['From'],email_msg['To'],email_msg.as_string())\n",
        "server.quit()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "vHl4su15doAq",
        "outputId": "599c4cd1-3ea3-4eb8-cd57-6bea4af058a9"
      },
      "execution_count": 186,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "(221, b'2.0.0 closing connection k9sm5945799ilv.61 - gsmtp')"
            ]
          },
          "metadata": {},
          "execution_count": 186
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "### TESTES"
      ],
      "metadata": {
        "id": "jPoZcioG9u6A"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "# 2 - CONTRUIR O EMAIL TIPO MIME\n",
        "\n",
        "corpo = '<b style = \"color: pink\">Olá, tudo bem? </b><p>♥ &hearts; &#10048; &#10084;\t&#10085; &#8986; \t&#9810; &#99818; \t&#9730; \t&#9760;</p><img src=\"//content//nero.png\" alt = \"erro\"> '\n",
        "#<img alt=\"Foto\" src=\"cid:/content/Foto.jpeg\" /> </b> '\n",
        "email_msg = MIMEMultipart()\n",
        "email_msg['From'] = login\n",
        "email_msg['To'] = 'deboraadotto@gmail.com'\n",
        "email_msg['Subject'] = \"TESTANDO\"\n",
        "email_msg.attach(MIMEText(corpo,'html'))\n",
        "\n",
        "\n",
        "# anexo de arquivo\n",
        "#abrimos o arquivo em modo leitura e binary\n",
        "##cam_arquivo = \"/content/clearsale.png\"\n",
        "##attchment = open(cam_arquivo,'rb') # r de ready e b de binary (leitura binária)\n",
        "\n",
        "# lemos o arquivo no modo binario e jogamos codificado em base 64 (que é o que o e-mail precisa)\n",
        "##att = MIMEBase('application','octet-stream')\n",
        "##att.set_payload(attchment.read())\n",
        "##encoders.encode_base64(att)\n",
        "\n",
        "#adicionamos o cabeçalho no tipo anexo de e-mail\n",
        "##att.add_header('Content-Disposition',f'attachment; filename=teste.png')\n",
        "##attchment.close()\n",
        "##email_msg.attach(att)\n",
        "\n",
        "#########################\n",
        "\n",
        "##with open('/content/nero.png','rb') as f:\n",
        "##  mime = MIMEImage(f.read(),_subtype='png')\n",
        "##  ##encoders.encode_base64(mime)\n",
        "##  mime.add_header('Content-Disposition','attachment', filename='teste.png')\n",
        "##  email_msg.attach(mime)\n",
        "\n",
        "################################\n"
      ],
      "metadata": {
        "id": "Jf4wWqS0yykt"
      },
      "execution_count": 184,
      "outputs": []
    }
  ]
}
